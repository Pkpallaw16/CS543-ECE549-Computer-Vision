# %%
######
#@title 1. Connect Colab to your google drive
######

# %load_ext autoreload
# %autoreload 2

from google.colab import drive
drive.mount('/content/drive')
#### change to the directory in your drive. 
# %cd "/content/drive/MyDrive/corners"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/corners

# %%
######
#@title 2. Install Dependencies. 
######

## Install dependencies from requirements
# !pip install -r requirements.txt

## Install extension module for evalution
#!python3 setup.py build_ext --inplace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 61.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Cython: filename=Cython-0.29.2-cp38-cp38-linux_x86_64.whl size=6469566 sha256=a83bc55702749c37c324c12f6a6df1a2b488adb97189caef28ffaf71ce9a8979
#   Stored in directory: /root/.cache/pip/wheels/7d/b2/4d/376d7ffe629acca6dfa56d4e10c2fb522acab9034107284c2a
# Successfully built Cython
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.33
#     Uninstalling Cython-0.29.33:
#       Successfully uninstalled Cython-0.29.33
# ...

# %%
######
#@title 3. Run your script
######

## Modify the contour_solve.py to implement the contour detector 
# !python3 corner_demo.py --mode vis --output_dir output/nidia
# Out:
# Writing visualization to output/nidia/vis/beckman_vis.png

# %%
# !python3 corner_demo.py --mode benchmark --output_dir output/output17/part1_1.5_0.05
# Out:
# Running detector:
# 100% 80/80 [02:35<00:00,  1.94s/it]
# Evaluating:
# 100% 80/80 [00:00<00:00, 205.88it/s]
#                   ap: 0.335891
# runtime (in seconds): 1.930466
# Saving evaluation:

# %%
# !python3 corner_plot.py --dirs output/output17/part1_0.4_0.05,output/output17/part1_0.8_0.05,output/output17/part1_1_0.05,output/output17/part1_1.5_0.05 --names "sigma=0.4","sigma=0.8","sigma=1","sigma=1.5" --out_file_name output/output17
# Out:
#            sigma=0.4: 0.304099  , 1.908888
#            sigma=0.8: 0.452500  , 1.945614
#              sigma=1: 0.409550  , 1.935273
#            sigma=1.5: 0.335891  , 1.930466

# %%
# !python3 corner_plot.py --dirs output/part3_0.7_0.03,output/part4_1_0.05,output/part5_0.8_0.08,output/part6_0.4_0.04,output/part7_0.6_0.03 --names 3,4,5,6,7 "with NMS sigma and alpha"
# Out:
#                    3: 0.504366  , 0.582784
#                    4: 0.449955  , 0.576860
#                    5: 0.475877  , 0.558785
#                    6: 0.351686  , 0.602502
#                    7: 0.505074  , 0.571351

# %%
# !python3 corner_demo.py --mode benchmark --output_dir output/part2
# Out:
# Running detector:
# 100% 80/80 [00:40<00:00,  1.96it/s]
# Evaluating:
# 100% 80/80 [00:00<00:00, 210.24it/s]
#                   ap: 0.492914
# runtime (in seconds): 0.500148
# Saving evaluation:

# %%
from scipy.sparse import load_npz
import numpy as np
data = np.load('/content/drive/MyDrive/corners/output/demo/metrics.npz',allow_pickle=True)

# %%
data["precision"]
# Out:
# array([0.05263158, 0.05263158, 0.05263158, ..., 0.00427663, 0.00427658,
#        0.00427652])

# %%
data.files
print(data['precision'])
# Out:
# [0.05263158 0.05263158 0.05263158 ... 0.00427663 0.00427658 0.00427652]

# %%
from scipy import ndimage

# apply Sobel filter in x direction
grad_x = ndimage.sobel(smoothed, axis=0, mode='reflect')

# apply Sobel filter in y direction
grad_y = ndimage.sobel(smoothed, axis=1, mode='reflect')

print(grad_x,grad_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-38a0a6b41bb0> in <module>
#       2
#       3 # apply Sobel filter in x direction
# ----> 4 grad_x = ndimage.sobel(smoothed, axis=0, mode='reflect')
#       5
#       6 # apply Sobel filter in y direction
#
# NameError: name 'smoothed' is not defined
