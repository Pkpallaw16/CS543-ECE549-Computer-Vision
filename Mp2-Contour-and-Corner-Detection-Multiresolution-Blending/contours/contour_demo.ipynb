# %%
######
#@title 1. Connect Colab to your google drive
######

# %load_ext autoreload
# %autoreload 2

from google.colab import drive
drive.mount('/content/drive',force_remount=True)
import os
print(os.getcwd())
#### change to the directory in your drive. 
# %cd "/content/drive/MyDrive/contours"
# Out:
# Mounted at /content/drive
# /content
# /content/drive/MyDrive/contours

# %%
######
#@title 2. Install Dependencies. 
######

## Install dependencies from requirements
# !pip install -r requirements.txt

## Install extension module for evalution
# !python3 setup.py build_ext --inplace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Cython: filename=Cython-0.29.2-cp38-cp38-linux_x86_64.whl size=6469646 sha256=aa916f5e662e8fe5427533085d1df4c877a85d06351ab1bd239a3494a047929e
#   Stored in directory: /root/.cache/pip/wheels/7d/b2/4d/376d7ffe629acca6dfa56d4e10c2fb522acab9034107284c2a
# Successfully built Cython
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.33
#     Uninstalling Cython-0.29.33:
#       Successfully uninstalled Cython-0.29.33
# ...
# running build_ext
# ...

# %%
######
#@title 3. Run your script
######

## Modify the contour_solve.py to implement the contour detector 
# !python3 contour_demo.py --output_dir output/bell_whistle
# Out:
# python3: can't open file 'contour_demo.py': [Errno 2] No such file or directory

# %%
# !python3 contour_plot.py --dirs output/part1,output/part2,output/part3 --names "Minimize artifacts","Smoothing","Non-maximum Suppression"
# Out:
# Minimize artifacts
#                threshold: 0.200000
#     overall max F1 score: 0.423994
#     average max F1 score: 0.483838
#                       AP: 0.359034
# ==    Minimize artifacts: 0.423994, 0.483838, 0.359034, 0.015779
# Smoothing
#                threshold: 0.050000
#     overall max F1 score: 0.525418
#     average max F1 score: 0.543403
#                       AP: 0.414946
# ==             Smoothing: 0.525418, 0.543403, 0.414946, 0.024693
# Non-maximum Suppression
#                threshold: 0.250000
#     overall max F1 score: 0.556573
#     average max F1 score: 0.584217
#                       AP: 0.536436
# == Non-maximum Suppression: 0.556573, 0.584217, 0.536436, 0.992792

# %%
# from scipy.sparse import load_npz
# import numpy as np
# data = np.load('/content/drive/MyDrive/contours/output/demo/metrics.npz',allow_pickle=True)

# %%
# data["precision"]

# %%
# data.files
# print(data['precision'])

# %%
# from scipy import ndimage

# # apply Sobel filter in x direction
# grad_x = ndimage.sobel(smoothed, axis=0, mode='reflect')

# # apply Sobel filter in y direction
# grad_y = ndimage.sobel(smoothed, axis=1, mode='reflect')

# print(grad_x,grad_y)
